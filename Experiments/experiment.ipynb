# %%
from preprocessing import *
from encoding_methods import *
from embedding_methods_w2v_fasttext import *
from embedding_method_kobert import *

# %% [markdown]
# # 1. Data Load and Preprocess

# %%
current_directory = input() # enter your directory that stores DPHR-SP. This directory should end with '~/DPHR-SP.csv'.
data = preprocess(current_directory)

# %% [markdown]
# # 2. Binary Classification

# %% [markdown]
# ## 2-1. Encoding Methods

# %% [markdown]
# ### 2-1-1. Simple Spacing

# %%
og_cv_target_rf(data)
# Out:
#            not helpful     helpful  accuracy    macro avg  weighted avg
# precision     0.598266    0.685535  0.662308     0.641900      0.651500
# recall        0.408284    0.824716  0.662308     0.616500      0.662308
# f1-score      0.485346    0.748712  0.662308     0.617029      0.645999
# support     507.000000  793.000000  0.662308  1300.000000   1300.000000
# 0.6623076923076923

# %% [markdown]
# ### 2-1-2. Mecab Tokenizer

# %%
mecab_cv_target_rf(data)
# Out:
#            not helpful     helpful  accuracy    macro avg  weighted avg
# precision     0.616798    0.704026  0.678462     0.660412      0.670007
# recall        0.463511    0.815889  0.678462     0.639700      0.678462
# f1-score      0.529279    0.755841  0.678462     0.642560      0.667482
# support     507.000000  793.000000  0.678462  1300.000000   1300.000000
# 0.6784615384615384

# %% [markdown]
# ### 2-1-3. Khaiii Tokenizer

# %%
khaiii_cv_target_rf(data)
# Out:
#            not helpful     helpful  accuracy    macro avg  weighted avg
# precision     0.633094    0.724802  0.695385     0.678948      0.689036
# recall        0.520710    0.807062  0.695385     0.663886      0.695385
# f1-score      0.571429    0.763723  0.695385     0.667576      0.688728
# support     507.000000  793.000000  0.695385  1300.000000   1300.000000
# 0.6953846153846154

# %% [markdown]
# ## 2-2. Embedding Methods

# %% [markdown]
# ### 2-2-1. Mecab + Word2Vec

# %%
mecab_w2v_target_rf(data)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_tr])
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ...

# %% [markdown]
# ### 2-2-2. Mecab + FastText

# %%
mecab_fasttext_target_rf(data)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_tr])
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ...

# %% [markdown]
# ### 2-2-3. Mecab + KoBERT

# %%
mecab_kobert_target_rf(data)
# Out:
#            not helpful     helpful  accuracy    macro avg  weighted avg
# precision     0.511111    0.641748  0.614615     0.576429      0.590799
# recall        0.272189    0.833544  0.614615     0.552866      0.614615
# f1-score      0.355212    0.725178  0.614615     0.540195      0.580892
# support     507.000000  793.000000  0.614615  1300.000000   1300.000000

# %% [markdown]
# # 3. Multi-class Classification

# %% [markdown]
# ## 3-1. Encoding Methods

# %% [markdown]
# ### 3-1-1. Mecab Tokenizer

# %%
mecab_cv_cat_rf(data)
# Out:
#                  cat1        cat2        cat3        cat4  accuracy  \
# precision    0.658333    0.693878    0.635036    0.714286  0.685422
# recall       0.537415    0.702479    0.604167    0.803213  0.685422
# f1-score     0.591760    0.698152    0.619217    0.756144  0.685422
# support    147.000000  242.000000  144.000000  249.000000  0.685422
#
#             macro avg  weighted avg
# precision    0.675383      0.682859
# recall       0.661818      0.685422
# f1-score     0.666318      0.682083
# support    782.000000    782.000000
# 0.6854219948849105

# %% [markdown]
# ### 3-1-2. Khaiii Tokenizer

# %%
khaiii_cv_cat_rf(data)
# Out:
#                  cat1        cat2        cat3        cat4  accuracy  \
# precision    0.680851    0.692308    0.628378    0.675768  0.672634
# recall       0.435374    0.706612    0.645833    0.795181  0.672634
# f1-score     0.531120    0.699387    0.636986    0.730627  0.672634
# support    147.000000  242.000000  144.000000  249.000000  0.672634
#
#             macro avg  weighted avg
# precision    0.669326      0.673115
# recall       0.645750      0.672634
# f1-score     0.649530      0.666213
# support    782.000000    782.000000
# 0.6726342710997443

# %% [markdown]
# ## 3-2. Embedding Methods

# %% [markdown]
# ### 3-2-1. Mecab + Word2Vec

# %%
mecab_w2v_cat_rf(data)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:94: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_tr])
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:95: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ...

# %% [markdown]
# ### 3-2-2. Mecab + FastText

# %%
mecab_fasttext_cat_rf(data)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:223: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_tr])
# /home/administrator/jupyter/jinmo/PR/Final/embedding_methods_w2v_fasttext.py:224: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ...
